# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# %%
X,y = make_moons(n_samples=100,noise=0.05)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_scaled = sc.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 0.65166046, -1.7246803 ],
#        [ 0.27095873, -1.4289284 ],
#        [-1.63264505,  0.39981289],
#        [-1.17961472,  1.09474669],
#        [-0.2992961 ,  1.45578303],
#        [ 0.43822727, -1.54962281],
#        [-1.68469217, -0.64033749],
#        [ 1.55498772, -0.72809356],
#        [-1.31332555,  1.09703945],
#        [ 1.64182635,  0.60713474],
#        [-0.5680325 ,  0.34760288],
#        [-0.23837491, -0.89478539],
#        [-0.09103306, -1.04855701],
#        [ 0.87867042, -1.41995737],
#        [ 0.19239154,  0.9783684 ],
#        [ 1.5613552 , -0.58501796],
#        [ 0.39059028,  0.6342703 ],
#        [-1.28042254,  0.87468926],
#        [-0.7134086 ,  1.50598729],
#        [ 1.34871033, -1.10400407],
#        [-1.70927716, -0.01967723],
#        [-0.53278118,  0.27864444],
#        [ 0.78928254, -1.44796996],
#        [-0.24092852,  1.47744788],
#        [ 0.56847907,  0.10609693],
#        [ 1.73678377,  0.18464737],
#        [ 0.47461534,  0.6163044 ],
#        [ 1.67208182,  0.18529939],
#        [-0.11953599, -0.88090981],
#        [-1.56038185,  0.53021185],
#        [ 0.16638778, -1.32663362],
#        [-0.78910555,  1.60798206],
#        [ 1.61969121,  0.09765649],
#        [ 0.40826087,  0.35996248],
#        [ 1.13480344, -1.1898704 ],
#        [ 0.19924337,  0.85917113],
#        [-1.65466515, -0.28573528],
#        [-0.34089366,  1.49173639],
#        [ 0.21462921, -1.41105153],
#        [ 1.60726418,  0.03666598],
#        [ 0.59105702, -0.4039419 ],
#        [ 0.40812371, -1.31138276],
#        [ 1.59534234, -0.1773082 ],
#        [-1.74917509,  0.0493049 ],
#        [ 0.03021147, -1.21301182],
#        [-0.86717618,  1.38804926],
#        [-1.64296072,  0.07288003],
#        [ 0.08345768, -1.34832776],
#        [-1.61832437,  0.19324302],
#        [ 1.02215065, -1.38208867],
#        [-0.46383177, -0.02264188],
#        [ 0.69312853, -1.66554098],
#        [-0.56838261,  0.14320272],
#        [ 0.56676202, -0.05535509],
#        [-1.5275375 ,  0.77918258],
#        [-0.19909995,  1.48373007],
#        [-0.60260904,  0.47580971],
#        [-0.96405509,  1.4612902 ],
#        [-1.27711245,  1.25462801],
#        [ 0.84996886, -1.39376259],
#        [ 0.57851221, -1.54530284],
#        [ 1.30692634, -0.93770974],
#        [-1.41516979,  0.84716477],
#        [ 1.63251329, -0.36853231],
#        [-0.37793581, -0.70788964],
#        [ 0.23162707, -1.50253209],
#        [ 0.11287537,  1.27390661],
#        [-0.40106142, -0.39474056],
#        [ 1.31091773, -1.12633228],
#        [ 1.54410451, -0.59338657],
#        [ 0.47511798,  0.02695628],
#        [-1.60246612,  0.54137394],
#        [-0.29058335, -0.95748828],
#        [ 1.1187458 , -1.19771055],
#        [ 1.68774299, -0.3128383 ],
#        [-1.08466453,  1.41644964],
#        [-0.61327258,  1.37629865],
#        [-1.7923115 , -0.308533  ],
#        [-0.26499852, -0.73873533],
#        [ 0.64206015, -0.53590212],
#        [ 1.50444679, -0.81360655],
#        [-1.08646732,  1.31300613],
#        [-0.49645187,  1.52601623],
#        [ 1.33560241, -0.86257324],
#        [ 0.6144177 , -0.2864403 ],
#        [ 0.18429562,  0.62613735],
#        [-0.43455807, -0.37058971],
#        [-0.00376733,  1.28128367],
#        [-1.45263371,  0.81296126],
#        [-0.54548958, -0.115035  ],
#        [ 0.06072797,  1.07739596],
#        [-0.87249076,  1.30790214],
#        [ 0.87273272, -1.44581799],
#        [-0.46677637,  1.69379701],
#        [ 0.47571714,  0.23298837],
#        [ 0.04202493,  1.01959146],
#        [ 0.01368736,  1.35065077],
#        [-0.19985135, -1.07957694],
#        [-0.48449632, -0.02508376],
#        [ 0.20822608,  1.03308849]])

# %%
dbscan = DBSCAN(eps=0.3)

# %%
labels = dbscan.fit_predict(X_scaled)

# %%
plt.scatter(X[:,0],X[:,1],c=labels)
